# %% [markdown]
# # Customer Churn Prediction Testing Notebook
#
# This notebook sends prediction requests to the deployed model API and validates that the cloud deployment responds correctly.

# %%
import json
import requests

API_URL = 'https://your-cloud-app-url.example.com/predict'

payload = {
    'customer_age': 35,
    'gender': 'Male',
    'contract_type': 'Month-to-Month',
    'monthly_charges': 72.5,
    'tenure': 12,
    'support_calls': 4,
    'total_usage': 210,
    'satisfaction_score': 2,
}

response = requests.post(API_URL, json=payload, timeout=30)
print(response.status_code)
print(response.json())
